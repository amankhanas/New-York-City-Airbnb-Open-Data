# %% [markdown]
# # Математико-статистический анализ
# В этом ноутбуке рассчитываются описательные статистики, корреляции и взаимосвязи между признаками.

# %%
import pandas as pd

df = pd.read_csv('../data/processed/airbnb_clean.csv')
numeric = df.select_dtypes(include=['int64', 'float64'])
desc = numeric.describe().T
corr = numeric.corr()

print('Descriptive statistics:')
display(desc)
# Out:
# Descriptive statistics:
#                                   count          mean           std  \
# id                              45912.0  1.889813e+07  1.092050e+07
# host_id                         45912.0  6.632877e+07  7.756370e+07
# latitude                        45912.0  4.072849e+01  5.533318e-02
# longitude                       45912.0 -7.395074e+01  4.647310e-02
# price                           45912.0  1.199991e+02  6.813300e+01
# minimum_nights                  45912.0  6.937968e+00  1.985950e+01
# number_of_reviews               45912.0  2.394019e+01  4.531622e+01
# reviews_per_month               45912.0  1.107626e+00  1.612588e+00
# calculated_host_listings_count  45912.0  6.640268e+00  3.101183e+01
# availability_365                45912.0  1.093759e+02  1.302844e+02
#
#                                        min           25%           50%  \
# id                              2539.00000  9.435824e+06  1.952354e+07
# host_id                         2438.00000  7.720366e+06  3.028359e+07
# latitude                          40.49979  4.068924e+01  4.072178e+01
# longitude                        -74.24442 -7.398194e+01 -7.395437e+01
# price                             10.00000  6.500000e+01  1.000000e+02
# minimum_nights                     1.00000  1.000000e+00  2.000000e+00
# number_of_reviews                  0.00000  1.000000e+00  5.000000e+00
# reviews_per_month                  0.00000  5.000000e-02  3.800000e-01
# calculated_host_listings_count     1.00000  1.000000e+00  1.000000e+00
# availability_365                   0.00000  0.000000e+00  3.900000e+01
#
#                                          75%           max
# id                              2.891339e+07  3.648724e+07
# host_id                         1.055121e+08  2.743213e+08
# latitude                        4.076339e+01  4.091306e+01
# longitude                      -7.393433e+01 -7.371299e+01
# price                           1.590000e+02  3.340000e+02
# minimum_nights                  5.000000e+00  1.250000e+03
# number_of_reviews               2.400000e+01  6.290000e+02
# reviews_per_month               1.620000e+00  5.850000e+01
# calculated_host_listings_count  2.000000e+00  3.270000e+02
# availability_365                2.170000e+02  3.650000e+02

# %%
print('Correlation matrix:')
display(corr)
# Out:
# Correlation matrix:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.581488 -0.008036   0.101322
# host_id                         0.581488  1.000000  0.015950   0.144259
# latitude                       -0.008036  0.015950  1.000000   0.091366
# longitude                       0.101322  0.144259  0.091366   1.000000
# price                          -0.017915 -0.034762  0.068747  -0.306968
# minimum_nights                 -0.013737 -0.017951  0.025907  -0.064246
# number_of_reviews              -0.320481 -0.136624 -0.012497   0.053794
# reviews_per_month               0.178934  0.208244 -0.017957   0.140482
# calculated_host_listings_count  0.125603  0.147271  0.021423  -0.107659
# availability_365                0.073281  0.193633 -0.017405   0.096962
#
#                                    price  minimum_nights  number_of_reviews  \
# id                             -0.017915       -0.013737          -0.320481
# host_id                        -0.034762       -0.017951          -0.136624
# latitude                        0.068747        0.025907          -0.012497
# longitude                      -0.306968       -0.064246           0.053794
# price                           1.000000        0.031476          -0.027606
# minimum_nights                  0.031476        1.000000          -0.082860
# number_of_reviews              -0.027606       -0.082860           1.000000
# reviews_per_month              -0.047293       -0.127767           0.593746
# calculated_host_listings_count  0.174409        0.133659          -0.070534
# availability_365                0.066670        0.146426           0.183560
#
#                                 reviews_per_month  \
# id                                       0.178934
# host_id                                  0.208244
# latitude                                -0.017957
# longitude                                0.140482
# price                                   -0.047293
# minimum_nights                          -0.127767
# number_of_reviews                        0.593746
# reviews_per_month                        1.000000
# calculated_host_listings_count          -0.051050
# availability_365                         0.171385
#
#                                 calculated_host_listings_count  \
# id                                                    0.125603
# host_id                                               0.147271
# latitude                                              0.021423
# longitude                                            -0.107659
# price                                                 0.174409
# minimum_nights                                        0.133659
# number_of_reviews                                    -0.070534
# reviews_per_month                                    -0.051050
# calculated_host_listings_count                        1.000000
# availability_365                                      0.225639
#
#                                 availability_365
# id                                      0.073281
# host_id                                 0.193633
# latitude                               -0.017405
# longitude                               0.096962
# price                                   0.066670
# minimum_nights                          0.146426
# number_of_reviews                       0.183560
# reviews_per_month                       0.171385
# calculated_host_listings_count          0.225639
# availability_365                        1.000000

# %%
price_corr = corr['price'].sort_values(ascending=False)
print('Correlation with price:')
display(price_corr)
# Out:
# Correlation with price:
# price                             1.000000
# calculated_host_listings_count    0.174409
# latitude                          0.068747
# availability_365                  0.066670
# minimum_nights                    0.031476
# id                               -0.017915
# number_of_reviews                -0.027606
# host_id                          -0.034762
# reviews_per_month                -0.047293
# longitude                        -0.306968
# Name: price, dtype: float64
